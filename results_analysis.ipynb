# %%
import pandas as pd


var_mapping = {
                'feed_air/comp_1.P_1' : 'P1',
                'comp_1/v_6.F_7' : 'F7',
                'comp_1/v_6.P_2' : 'P2',
                'react_1.T_reg' : 'T_reg',
                'react_1.L_sp' : 'L_sp',
                'react_1.P_6' : 'P6',
                'react_1/v_7.F_sg' : 'F_sg',
                'react_1/v_7.T_cyc' : 'T_cyc',
                'v_7/prod_stack.X_co' : 'C_cosg',
                'v_7/prod_stack.X_co2' : 'C_co2sg',
                'react_1/v_2.F_rgc' : 'F_rgc',
                'react_2.T_r' : 'T_r',
                'react_2.P_4' : 'P4',
                'react_2/v_3.F_sc' : 'F_sc',
                'feed_feedstream/furn_1.F_3' : 'F3',
                'feed_feedstream/furn_1.T_1' : 'T1',
                'feed_fuel/v_1.F_5' : 'F5',
                'furn_1.T_3' : 'T3',
                'furn_1/react_2.T_2' : 'T2',
                'distil_1.T_20' : 'T_20',
                'distil_1.T_10' : 'T_10',
                'distil_1.T_fra' : 'T_fra',
                'distil_1.P_5' : 'P5',
                'v_11/prod_lightoil.F_lco' : 'F_LCO',
                'v_10/prod_heavynaptha.F_hn' : 'F_HN',
                'v_9/prod_lightnaptha.F_ln' : 'F_LN',
                'v_8/distil_1.F_reflux' : 'F_Reflux',
                'comp_2/prod_lpg.F_lpg' : 'F_LPG',
                'distil_1/prod_slurry.F_slurry' : 'F_Slurry',
                'ACAB' : 'ACAB',
                'AWGC' : 'AWGC',
                'Pos_1' : 'V1',
                'Pos_2' : 'V2',
                'Pos_3' : 'V3',
                'Pos_4' : 'V4',
                'Pos_6' : 'V6',
                'Pos_7' : 'V7',
                'Pos_8' : 'V8',
                'Pos_9' : 'V9',
                'Pos_10' : 'V10',
                'Pos_11' : 'V11',
                }


data_files = ['NOC_stableFeedFlow_outputs.csv',
              'NOC_varyingFeedFlow_outputs.csv',
              'CAB_valveLeak_outputs.csv',
              'condEff_decrease_outputs.csv',
              'deltaP_increase_outputs.csv',
              'Fhn_sensorDrift_outputs.csv',
              'UAf_decrease_outputs.csv']
file_ind = 1
data = pd.read_csv(rf'C:\Users\byron\OneDrive\Documents\Year 4\CPE440\Final Project\Code Repositiory\Data\{data_files[file_ind]}')
# additional_vars = ['Time', 'T_atm', 'deltaP', 'Fair', 'T_cyc-T_reg', 'FV11']
# data = data.drop(columns = additional_vars)

# %% [markdown]
# ## Combustion air blower

# %%
from test_cab_sections import test_cab_models

cab = test_cab_models(data, var_mapping)
cab.model_ctrl()

cab_kn_scores = cab.knowledge_scores
cab_scores = cab.comb_data_store
# Out:
# c:\Users\byron\OneDrive\Documents\Year 4\CPE440\Final Project\Code Repositiory\test_cab_sections.py:239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   knowledge_data[itr_dummy_node] = model.data_orig[var_name]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
from analyse_graphs import analyse_graphs

analyse_graphs.kn_score_vs_graph_score(cab_scores)

# %%
analyse_graphs.graph_score_for_mode(cab_scores, 0)
analyse_graphs.graph_score_for_mode(cab_scores, 1)

# %%
top_three = analyse_graphs.find_top_three_graphs(cab_scores)
for itr in top_three:

    graph = analyse_graphs.visualise_graph(itr[0])
    print(itr[0]['graph score'])
# Out:
# 184288.1128697358
# 184269.19576454847
# 184251.88332941086

# %% [markdown]
# ## Regenerator

# %%
from test_react1_sections import test_react1_models

model = test_react1_models(data, var_mapping)
model.model_ctrl()

react1_kn_scores = cab.knowledge_scores
react1_scores = cab.comb_data_store
# Out:
# []
# []
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# []
# {}
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 from test_react1_sections import test_react1_models
#       3 model = test_react1_models(data, var_mapping)
# ----> 4 model.model_ctrl()
#       6 react1_kn_scores = cab.knowledge_scores
#       7 react1_scores = cab.comb_data_store
#
# File c:\Users\byron\OneDrive\Documents\Year 4\CPE440\Final Project\Code Repositiory\test_react1_sections.py:93, in test_react1_models.model_ctrl(model)
#      88 graph = {'nodes' : model.nodes,
#      89          'dummy vars' : model.dummy_nodes_struct,
#      90          'edges' : model.edges,
#      91          'forbidden' : model.forbid_edges}
#      92 fges_obj = run_fges(graph, model.required_data, 'run fges')
# ---> 93 fges_obj.run_fges_ctrl()
#      95 # Plot best DAG of MEC
#      96 model.plot_best_dag_in_class(itr_comb, fges_obj, False)
#
# File c:\Users\byron\OneDrive\Documents\Year 4\CPE440\Final Project\Code Repositiory\test_run_fges.py:51, in run_fges.run_fges_ctrl(fges_obj)
#      48 # fges_obj.adj_dtype()
#      50 fges_obj.build_knowledge()
# ---> 51 fges_obj.perform_fges()
#      52 fges_obj.categorise_edges()
#      53 fges_obj.calc_avg_deg()
#
# File c:\Users\byron\OneDrive\Documents\Year 4\CPE440\Final Project\Code Repositiory\test_run_fges.py:122, in run_fges.perform_fges(fges_obj)
#     119 self.setFaithfulnessAssumed(False)
#     120 # self.setVerbose(True)
#     121 # self.setMeekVerbose(True)
# --> 122 fges_obj.cpdag = self.search()
#     123 mat = tr.graph_to_matrix(fges_obj.cpdag, nullEpt=0, circleEpt=1, arrowEpt=2, tailEpt=3)
#     124 # print(f'final score: {self.getModelScore()}')
#     125 # print(mat)
#
# KeyboardInterrupt:
